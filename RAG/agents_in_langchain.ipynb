# %%
import os
os.environ["GROQ_API_KEY"]="..."

# %%
# %pip install -U langchain_community langchain-core requests duckduckgo-search ddgs
# Out:
# ...
#   Using cached langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached langchain_core-1.4.9-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# ...
# Using cached langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
# Using cached langchain_core-1.4.9-py3-none-any.whl (558 kB)
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# ...
#    ---------------------------------------- 0.0/657.4 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/657.4 kB ? eta -:--:--
#    ---------------------------------------- 657.4/657.4 kB 1.9 MB/s  0:00:00
# ...
#
#   Attempting uninstall: langsmith
#
#     Found existing installation: langsmith 0.1.147
#
#     Uninstalling langsmith-0.1.147:
#
#       Successfully uninstalled langsmith-0.1.147
#
#    ---------------------------------------- 0/4 [langsmith]
#    ---------------------------------------- 0/4 [langsmith]
# ...

# %%
# %pip install -U langchain  langchain-groq
# Out:
# ...
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached langchain-1.3.13-py3-none-any.whl.metadata (6.1 kB)
# ...
# Using cached langchain-1.3.13-py3-none-any.whl (136 kB)
# ...
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.1.20
#     Uninstalling langchain-0.1.20:
#       Successfully uninstalled langchain-0.1.20
# ...

# %%
from langchain_community.tools import DuckDuckGoSearchRun
search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke("top new in india today")

# %%
results
# Out:
# "Times of India brings the Latest News & Breaking News Headlines from India & around the World. Read Latest News Today on Sports, Business, Health & Fitness, Bollywood & Entertainment, Blogs ... Get the latest India news, breaking headlines, political developments, government updates, weather alerts, crime news and state coverage at CNBC TV18. Latest News Today: Follow today's news updates and recent stories from India and across the globe, covering politics, business, technology, and sports. Stay informed with the latest news today. Get breaking news, live updates, and top headlines from India and around the world on News24 The latest news headlines on Life Style, Business, Politics, Hollywood and News from across the world at The Times of India."

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(
    model="llama-3.1-8b-instant",
     temperature=0.9)

# %%
llm.invoke("who made u real name?")
# Out:
# AIMessage(content="I'm an AI, and I don't have a real name in the classical sense. My creators are Meta AI, and I'm a model of the Dialog system.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 35, 'prompt_tokens': 41, 'total_tokens': 76, 'completion_time': 0.068054972, 'completion_tokens_details': None, 'prompt_time': 0.005203714, 'prompt_tokens_details': None, 'queue_time': 0.052802385, 'total_time': 0.073258686}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f6448-71d2-7933-8002-afa0c9406aa5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 35, 'total_tokens': 76})

# %%
from langgraph.prebuilt import create_react_agent

# %%
# %pip install langchainhub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import langchainhub as hub

# %%
#Step 2: pull the ReAct prompt from Langchain Hub
from langchainhub.client import Client

client = Client()
# Pull a prompt
prompt = client.pull("hwchase17/react")
# pulls the standard ReAct agent prompt
# Out:
# C:\Users\vighnesh\AppData\Local\Temp\ipykernel_15256\2190695120.py:6: DeprecationWarning: The `langchainhub sdk` is deprecated.
# Please use the `langsmith sdk` instead:
#   pip install langsmith
# Use the `pull_prompt` method.
#   prompt = client.pull("hwchase17/react")

# %%
# %pip install langchain.agent
# Out:
# ...
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# No imports needed - create_react_agent is already imported in a previous cell

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Create a simple QA chain without ReAct agent
qa_prompt = PromptTemplate(
    template="""You are a helpful travel assistant. Answer the user's question accurately.
    
Available tools:
- You can perform web searches to find current travel information

Question: {input}
Answer: """,
    input_variables=["input"]
)

# Create a simple chain
simple_chain = qa_prompt | llm | StrOutputParser()
agent = simple_chain

# %%
response = agent.invoke({"input":"3 ways to reach goa from delhi"})
print(response)
# Out:
# There are multiple ways to reach Goa from Delhi, and I'd be happy to help you with that. Here are the top 3 ways to reach Goa from Delhi:
#
# 1. **By Flight**: The fastest way to reach Goa from Delhi is by flight. The total travel time is around 1.5 hours, and multiple flights operate daily from Indira Gandhi International Airport (DEL) to Dabolim Airport (GOI) in Goa. You can book flights with airlines like IndiGo, GoFirst, SpiceJet, and Air India.
#
# 2. **By Train**: Another popular option is by train. The total travel time is around 24-30 hours, depending on the type of train and route. You can take the Rajdhani Express or Goa Express from New Delhi Railway Station (NDLS) to Madgaon Junction (MAO) or Vasco-da-Gama (VSG) in Goa.
#
# ...
